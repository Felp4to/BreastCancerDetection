# %%
import sys
import os

# %%
# Specifica il percorso alla directory che contiene il tuo file .py
directory_path = '../preprocessing/py'
sys.path.append(directory_path)

# %%
import fourier as fourier  # type: ignore

# %%
PATH_CANCER = "../images/cancer"

# %%
def give_list_images(path):
    files = os.listdir(path)
    paths = [os.path.join(path, nome) for nome in files]
    return paths

cancer_list = give_list_images(PATH_CANCER)

print(cancer_list)
# Out:
# ['../images/cancer\\8975_idx5_x1001_y1301_class1.png', '../images/cancer\\8975_idx5_x1301_y1301_class1.png', '../images/cancer\\8975_idx5_x1451_y1501_class1.png', '../images/cancer\\8975_idx5_x1501_y1401_class1.png', '../images/cancer\\8975_idx5_x1701_y1101_class1.png', '../images/cancer\\8975_idx5_x1751_y551_class1.png', '../images/cancer\\8975_idx5_x2001_y1101_class1.png', '../images/cancer\\8975_idx5_x2251_y651_class1.png']

# %%
for img_path in cancer_list:
    fourier_img = fourier.apply_fourier_denoising(img_path, (50, 50, 3), 0, 1, 1, 1)
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# psnr:  51.141103565318915
# lpips:  1.6114011032186681e-06
# mse:  0.5
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# psnr:  51.141103565318915
# lpips:  1.4733914213138632e-06
# mse:  0.5
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# psnr:  51.141103565318915
# lpips:  2.2146391529531684e-06
# mse:  0.5
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# psnr:  51.141103565318915
# lpips:  1.8873666931540356e-06
# mse:  0.5
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# psnr:  51.141103565318915
# lpips:  2.1614000615954865e-06
# mse:  0.5
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# psnr:  51.141103565318915
# lpips:  1.6142126924023614e-06
# mse:  0.5
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# psnr:  51.141103565318915
# lpips:  1.412122060173715e-06
# mse:  0.5
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# psnr:  51.141103565318915
# lpips:  1.6355527350242482e-06
# mse:  0.5
