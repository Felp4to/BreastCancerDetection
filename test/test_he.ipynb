# %%
import sys
import os

# %%
# Specifica il percorso alla directory che contiene il tuo file .py
directory_path = '../preprocessing/py'
sys.path.append(directory_path)

# %%
import he as he  # type: ignore

# %%
PATH_NO_CANCER = "../images/no_cancer"
PATH_SI_CANCER = "../images/si_cancer"

# %%
PATH = "../images/1-126.jpg"

# %%
def give_list_images(path):
    files = os.listdir(path)
    paths = [os.path.join(path, nome) for nome in files]
    return paths

no_cancer_list = give_list_images(PATH_NO_CANCER)
si_cancer_list = give_list_images(PATH_SI_CANCER)

print(no_cancer_list)
print(si_cancer_list)
# Out:
# ['../images/no_cancer\\9073_idx5_x101_y1501_class0.png', '../images/no_cancer\\9073_idx5_x1201_y501_class0.png', '../images/no_cancer\\9073_idx5_x201_y1601_class0.png', '../images/no_cancer\\9073_idx5_x51_y1451_class0.png']
# ['../images/si_cancer\\9073_idx5_x1001_y1001_class1.png', '../images/si_cancer\\9073_idx5_x1051_y451_class1.png', '../images/si_cancer\\9073_idx5_x1201_y801_class1.png', '../images/si_cancer\\9073_idx5_x1301_y651_class1.png']

# %%
for img_path in no_cancer_list:
    he_img = he.apply_histogram_equalization(img_path, (50, 50, 3), 1, 1)
# Out:
# Peak:  28.117927065790177
# Mse:  100.29693333333333
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# LPIPS:  0.3336213231086731
# Peak:  27.826943983833917
# Mse:  107.2472
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# LPIPS:  0.4444490373134613
# Peak:  28.75004496581358
# Mse:  86.71133333333333
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# LPIPS:  0.6426872611045837
# Peak:  28.271033211638454
# Mse:  96.82266666666666
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# LPIPS:  0.4529497027397156

# %%
for img_path in si_cancer_list:
    he_img = he.apply_histogram_equalization(img_path, (50, 50, 3), 0, 1)
# Out:
# Peak:  28.664971067173934
# Mse:  88.42666666666666
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# LPIPS:  0.4422769248485565
# Peak:  29.100772414593955
# Mse:  79.984
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# LPIPS:  0.5022698044776917
# Peak:  28.26594071262967
# Mse:  96.93626666666667
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# LPIPS:  0.356052041053772
# Peak:  28.549690038752956
# Mse:  90.80533333333334
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# LPIPS:  0.32924893498420715

# %%
denoised_image = he.apply_histogram_equalization(PATH, 1, 1)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 denoised_image = he.apply_histogram_equalization(PATH, 1, 1)
#
# File c:\Users\tardi\OneDrive\Documenti\Università\Artificial Intelligence from enginnering to arts\Project\Breast Cancer Detection\test\../preprocessing/py\he.py:17, in apply_histogram_equalization(path, target_size, histogram, show_result)
#      14 image = cv2.imread(path)
#      16 # Convert the image from BGR to HSV color space
# ---> 17 hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
#      19 # Split into H, S, and V channels (we will apply equalization to the V channel)
#      20 h, s, v = cv2.split(hsv_image)
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
