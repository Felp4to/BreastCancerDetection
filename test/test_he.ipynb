# %%
import sys
import os

# %%
# Specifica il percorso alla directory che contiene il tuo file .py
directory_path = '../preprocessing/py'
sys.path.append(directory_path)

# %%
import he as he  # type: ignore

# %%
PATH = "../images/1-126.jpg"

# %%
he.apply_histogram_equalization(PATH, 1, 1)
# Out:
# array([[247, 246, 246, ..., 255, 255, 255],
#        [246, 246, 246, ..., 255, 255, 255],
#        [246, 246, 246, ..., 255, 255, 255],
#        ...,
#        [  0,   0,   0, ..., 255, 255, 255],
#        [  0,   0,   0, ..., 255, 255, 255],
#        [  0,   0,   0, ..., 255, 255, 255]], dtype=uint8)
