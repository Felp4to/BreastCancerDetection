# %%
import sys
import os

# %%
# Specifica il percorso alla directory che contiene il tuo file .py
directory_path = '../preprocessing/py'
sys.path.append(directory_path)

# %%
import clahe as clahe
import he
import fuzzy
import wavelet

# %%
PATH = "../images/1-126.jpg"

# %%
clahe.apply_equalization_clahe(PATH, 0, 1, 2.0, (15, 15))
clahe.apply_equalization_clahe(PATH, 0, 1, 2.0, (8, 8))
