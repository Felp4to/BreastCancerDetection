# %%
import sys
import os

# %%
# Specifica il percorso alla directory che contiene il tuo file .py
directory_path = '../preprocessing/py'
sys.path.append(directory_path)

# %%
import fuzzy as fuzzy # type: ignore

# %%
PATH = "../images/1-126.jpg"

# %%
fuzzy.FuzzyContrastEnhance(PATH, 1)
# Out:
# array([[[211, 211, 211],
#         [210, 210, 210],
#         [209, 209, 209],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[209, 209, 209],
#         [209, 209, 209],
#         [208, 208, 208],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[210, 210, 210],
#         [210, 210, 210],
#         [209, 209, 209],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[  0,   0,   0],
#         [  0,   0,   0],
#         [  0,   0,   0],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[  0,   0,   0],
#         [  0,   0,   0],
#         [  0,   0,   0],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[  0,   0,   0],
#         [  0,   0,   0],
#         [  0,   0,   0],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)
