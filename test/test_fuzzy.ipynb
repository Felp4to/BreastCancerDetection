# %%
import sys
import os

# %%
# Specifica il percorso alla directory che contiene il tuo file .py
directory_path = '../preprocessing/py'
sys.path.append(directory_path)

# %%
import fuzzy as fuzzy # type: ignore

# %%
PATH_CANCER = "../images/cancer"

# %%
def give_list_images(path):
    files = os.listdir(path)
    paths = [os.path.join(path, nome) for nome in files]
    return paths

cancer_list = give_list_images(PATH_CANCER)

# %%
for img_path in cancer_list:
    fuzzy_img = fuzzy.FuzzyContrastEnhance(img_path, (50, 50, 3), 1, 1, 1)
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# psnr:  27.096821707055522
# lpips:  0.025879668071866035
# mse:  126.88146666666667
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# psnr:  27.838254023938372
# lpips:  0.051870692521333694
# mse:  106.96826666666666
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# psnr:  28.01059646009671
# lpips:  0.07925619930028915
# mse:  102.80653333333333
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# psnr:  27.38957590350704
# lpips:  0.0643397867679596
# mse:  118.6104
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# psnr:  28.13645890805034
# lpips:  0.12492917478084564
# mse:  99.86986666666667
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# psnr:  28.050880588861673
# lpips:  0.06677193939685822
# mse:  101.85733333333333
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# psnr:  28.20088793300368
# lpips:  0.0868874043226242
# mse:  98.3992
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# psnr:  27.82012463122512
# lpips:  0.09040303528308868
# mse:  107.41573333333334
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\lpips\weights\v0.1\alex.pth
# psnr:  28.279747016334223
# lpips:  0.09423019737005234
# mse:  96.62859375
