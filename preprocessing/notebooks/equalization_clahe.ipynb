# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Carica l'immagine in scala di grigi
img = cv2.imread("./1-126.jpg", cv2.IMREAD_GRAYSCALE)

# Crea l'oggetto CLAHE con un limite di contrasto
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))

# Applica CLAHE all'immagine
clahe_img = clahe.apply(img)

# %%
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 hist,bins = np.histogram(img.flatten(),256,[0,256])
#       2 cdf = hist.cumsum()
#       3 cdf_normalized = cdf * float(hist.max()) / cdf.max()
#
# AttributeError: 'NoneType' object has no attribute 'flatten'

# %%
hist,bins = np.histogram(clahe_img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
# Visualizza le immagini
plt.figure(figsize=(10,5))

plt.subplot(1, 2, 1)
plt.title('Immagine originale')
plt.imshow(img, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title('Immagine con CLAHE')
plt.imshow(clahe_img, cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 3825.5, 6600.5, -0.5)
