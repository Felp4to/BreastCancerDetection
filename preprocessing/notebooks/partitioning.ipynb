# %%
import sys

# %%
sys.path.append('../py')

# %%
import data_partitioning as datap

# %%
preprocessing_method = "no_denoising"
perc_dataset = 1

# %%
X_train, X_test, X_val, y_train, y_test, y_val = datap.prep_and_split(preprocessing_method, perc_dataset)
# Out:
# Number of Images of no cancer: 198738
# Number of Images of cancer : 78786
# Total Number of Images : 277524
# Caricamento immagini non tumorali...
# Non-cancer images: 100%|██████████| 198738/198738 [28:52<00:00, 114.69it/s]
# Caricamento immagini tumorali...
# Cancer images: 100%|██████████| 78786/78786 [07:47<00:00, 168.49it/s]
# 277524
# X shape: (277524, 50, 50, 3)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 X_train, X_test, X_val, y_train, y_test, y_val = datap.prep_and_split(preprocessing_method, perc_dataset)
#
# File c:\Users\tardi\OneDrive\Documenti\Università\Artificial Intelligence from enginnering to arts\Project\Breast Cancer Detection\preprocessing\notebooks\../py\data_partitioning.py:168, in prep_and_split(preprocessing_method, perc_dataset)
#     161 # TESTING
#     162 #X = np.array(X)[:1000]
# ...
