# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Contrast and Brightness

# %%
# read the input image
image = cv2.imread('./1-126.jpg')

# define the alpha and beta
alpha = 1.1 # Contrast control
beta = 5 # Brightness control

# call convertScaleAbs function
adjusted = cv2.convertScaleAbs(image, alpha=alpha, beta=beta)

# Imposta la figura per mostrare le immagini affiancate
plt.figure(figsize=(10, 5))

# Mostra l'immagine originale
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.title('Immagine Original')
plt.axis('off')

# Mostra l'immagine originale
plt.subplot(1, 2, 2)
plt.imshow(adjusted)
plt.title('Immagine with contrast and brightness')
plt.axis('off')
# Out:
# (-0.5, 3825.5, 6600.5, -0.5)
