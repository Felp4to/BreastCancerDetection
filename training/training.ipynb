# %%
import training as tr

# %%
#preprocessing_method = 'clahe'
#preprocessing_method = 'fuzzy'
#preprocessing_method = 'wavelet'
#preprocessing_method = 'he'
preprocessing_method = 'no_denoising'

# %%
# load partitions
X_train, X_val, X_test, y_train, y_val, y_test = tr.load_partitions(preprocessing_method)
# Out:
# ..\partitions\no_denoising\X_train.npy
# ..\partitions\no_denoising\X_test.npy
# ..\partitions\no_denoising\y_train.npy
# ..\partitions\no_denoising\y_test.npy
# ..\partitions\no_denoising\X_val.npy
# ..\partitions\no_denoising\y_val.npy

# %%
model = tr.create_model()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 50, 50, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 50, 50, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 25, 25, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 25, 25, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 25, 25, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 12, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 5, 5, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 5, 5, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 5, 5, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 308,162 (1.18 MB)
#  Trainable params: 307,458 (1.17 MB)
#  Non-trainable params: 704 (2.75 KB)

# %%
history = tr.training(model, preprocessing_method)
# Out:
# ..\partitions\no_denoising\X_train.npy
# ..\partitions\no_denoising\X_test.npy
# ..\partitions\no_denoising\y_train.npy
# ..\partitions\no_denoising\y_test.npy
# ..\partitions\no_denoising\X_val.npy
# ..\partitions\no_denoising\y_val.npy
# X_test shape: (600, 50, 50, 3)
# y_test shape: (600, 2)
# X_train shape: (4800, 50, 50, 3)
# y_train shape: (4800, 2)
# X_val shape: (600, 50, 50, 3)
# y_val shape: (600, 2)
# Epoch 1/25
#   3/150 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.6441 - loss: 0.9430
# c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.7516 - loss: 0.6597 - val_accuracy: 0.5183 - val_loss: 2.1374 - learning_rate: 0.0010
# Epoch 2/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8088 - loss: 0.4508 - val_accuracy: 0.5550 - val_loss: 0.9712 - learning_rate: 0.0010
# Epoch 3/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.8133 - loss: 0.4378 - val_accuracy: 0.6767 - val_loss: 0.5770 - learning_rate: 0.0010
# Epoch 4/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8217 - loss: 0.4222 - val_accuracy: 0.7400 - val_loss: 0.5827 - learning_rate: 0.0010
# Epoch 5/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8277 - loss: 0.4113
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8277 - loss: 0.4113 - val_accuracy: 0.5283 - val_loss: 1.1742 - learning_rate: 0.0010
# Epoch 6/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8397 - loss: 0.3884 - val_accuracy: 0.8017 - val_loss: 0.4362 - learning_rate: 2.0000e-04
# Epoch 7/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8394 - loss: 0.3869 - val_accuracy: 0.8033 - val_loss: 0.4682 - learning_rate: 2.0000e-04
# Epoch 8/25
# 148/150 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8483 - loss: 0.3681
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8481 - loss: 0.3684 - val_accuracy: 0.7967 - val_loss: 0.4486 - learning_rate: 2.0000e-04
# Epoch 9/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8405 - loss: 0.3749 - val_accuracy: 0.8233 - val_loss: 0.3922 - learning_rate: 4.0000e-05
# Epoch 10/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8401 - loss: 0.3753 - val_accuracy: 0.8333 - val_loss: 0.3998 - learning_rate: 4.0000e-05
# Epoch 11/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8480 - loss: 0.3643 - val_accuracy: 0.8367 - val_loss: 0.3852 - learning_rate: 4.0000e-05
# Epoch 12/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.8350 - loss: 0.3699 - val_accuracy: 0.8400 - val_loss: 0.3866 - learning_rate: 4.0000e-05
# Epoch 13/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8470 - loss: 0.3586
# Epoch 13: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.8470 - loss: 0.3586 - val_accuracy: 0.8367 - val_loss: 0.3883 - learning_rate: 4.0000e-05
# Epoch 14/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.8574 - loss: 0.3370 - val_accuracy: 0.8450 - val_loss: 0.3750 - learning_rate: 8.0000e-06
# Epoch 15/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8503 - loss: 0.3568 - val_accuracy: 0.8433 - val_loss: 0.3761 - learning_rate: 8.0000e-06
# Epoch 16/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8556 - loss: 0.3525
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.8555 - loss: 0.3525 - val_accuracy: 0.8283 - val_loss: 0.3798 - learning_rate: 8.0000e-06
# Epoch 17/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8478 - loss: 0.3506 - val_accuracy: 0.8300 - val_loss: 0.3819 - learning_rate: 1.6000e-06
# Epoch 18/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8491 - loss: 0.3535 - val_accuracy: 0.8350 - val_loss: 0.3710 - learning_rate: 1.6000e-06
# Epoch 19/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8321 - loss: 0.3686 - val_accuracy: 0.8467 - val_loss: 0.3827 - learning_rate: 1.6000e-06
# Epoch 20/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8491 - loss: 0.3551
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.8491 - loss: 0.3551 - val_accuracy: 0.8383 - val_loss: 0.3786 - learning_rate: 1.6000e-06
# Epoch 21/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8533 - loss: 0.3520 - val_accuracy: 0.8400 - val_loss: 0.3818 - learning_rate: 3.2000e-07
# Epoch 22/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8512 - loss: 0.3493
# Epoch 22: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8512 - loss: 0.3494 - val_accuracy: 0.8367 - val_loss: 0.3747 - learning_rate: 3.2000e-07
# Epoch 23/25
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.8472 - loss: 0.3501 - val_accuracy: 0.8383 - val_loss: 0.3796 - learning_rate: 6.4000e-08

# %%
tr.valuate_model(model, X_test, y_test)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8668 - loss: 0.3290
# Test Loss: 0.3801782429218292
# Test Accuracy: 0.8316666483879089
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85       319
#            1       0.84      0.79      0.82       281
#
#     accuracy                           0.83       600
#    macro avg       0.83      0.83      0.83       600
# weighted avg       0.83      0.83      0.83       600
#
# Accuracy: 0.8316666666666667

# %%
tr.plot_acc_loss(history)

# %%
prediction = model.predict(X_test)
prediction
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# array([[9.9998963e-01, 1.0377319e-05],
#        [9.9998903e-01, 1.0973700e-05],
#        [9.9959463e-01, 4.0536351e-04],
#        ...,
#        [2.2304750e-03, 9.9776959e-01],
#        [9.9391502e-01, 6.0849497e-03],
#        [9.9978191e-01, 2.1813283e-04]], dtype=float32)

# %%
print(prediction[0])
# Out:
# [9.9998963e-01 1.0377319e-05]
