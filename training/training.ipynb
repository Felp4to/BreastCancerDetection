# %%
import training as tr

# %%
preprocessing_method = 'no_denoising'
PATH = "../models/training_no_denoising"
history = tr.training(PATH, preprocessing_method, 1, 35)
# Out:
# ..\partitions\no_denoising
# ..\partitions\no_denoising\X_train.npy
# ..\partitions\no_denoising\X_test.npy
# ..\partitions\no_denoising\y_train.npy
# ..\partitions\no_denoising\y_test.npy
# ..\partitions\no_denoising\X_val.npy
# ..\partitions\no_denoising\y_val.npy
# X_test shape: (27753, 50, 50, 3)
# y_test shape: (27753, 2)
# X_train shape: (222019, 50, 50, 3)
# y_train shape: (222019, 2)
# c:\Users\tardi\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ...

# %%
preprocessing_method = 'clahe'
PATH = "../models/training_clahe"
history = tr.training(PATH, preprocessing_method)
# Out:
# ..\partitions\clahe\X_train.npy
# ..\partitions\clahe\X_test.npy
# ..\partitions\clahe\y_train.npy
# ..\partitions\clahe\y_test.npy
# ..\partitions\clahe\X_val.npy
# ..\partitions\clahe\y_val.npy
# X_test shape: (27753, 50, 50, 3)
# y_test shape: (27753, 2)
# X_train shape: (222019, 50, 50, 3)
# y_train shape: (222019, 2)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 50, 50, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 50, 50, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
preprocessing_method = 'fuzzy'
PATH = "../models/training_fuzzy"
history = tr.training(PATH, preprocessing_method)
# Out:
# ..\partitions\fuzzy\X_train.npy
# ..\partitions\fuzzy\X_test.npy
# ..\partitions\fuzzy\y_train.npy
# ..\partitions\fuzzy\y_test.npy
# ..\partitions\fuzzy\X_val.npy
# ..\partitions\fuzzy\y_val.npy
# X_test shape: (27753, 50, 50, 3)
# y_test shape: (27753, 2)
# X_train shape: (222019, 50, 50, 3)
# y_train shape: (222019, 2)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)               │ (None, 50, 50, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 50, 50, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
preprocessing_method = 'he'
PATH = "../models/training_he"
history = tr.training(PATH, preprocessing_method)
# Out:
# ..\partitions\he\X_train.npy
# ..\partitions\he\X_test.npy
# ..\partitions\he\y_train.npy
# ..\partitions\he\y_test.npy
# ..\partitions\he\X_val.npy
# ..\partitions\he\y_val.npy
# X_test shape: (27753, 50, 50, 3)
# y_test shape: (27753, 2)
# X_train shape: (222019, 50, 50, 3)
# y_train shape: (222019, 2)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 50, 50, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 50, 50, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
preprocessing_method = 'wavelet'
PATH = "../models/training_wavelet"
history = tr.training(PATH, preprocessing_method)
# Out:
# X_test shape: (27753, 50, 50, 3)
# y_test shape: (27753, 2)
# X_train shape: (222019, 50, 50, 3)
# y_train shape: (222019, 2)
# X_val shape: (27752, 50, 50, 3)
# y_val shape: (27752, 2)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 50, 50, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 50, 50, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 25, 25, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 25, 25, 64)     │        18,496 │
# ...

# %%
preprocessing_method = 'fourier'
PATH = "../models/training_fourier"
history = tr.training(PATH, preprocessing_method)
# Out:
# Error loading files: [Errno 2] No such file or directory: '..\\partitions\\fourier\\X_train.npy'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 preprocessing_method = 'fourier'
#       2 PATH = "../models/training_fourier"
# ----> 3 history = tr.training(PATH, preprocessing_method)
#
# File c:\Users\tardi\OneDrive\Documenti\Università\Artificial Intelligence from enginnering to arts\Project\Breast Cancer Detection\training\training.py:47, in training(root, preprocessing_method, epochs, batch_size, colab)
#      45 def training(root, preprocessing_method="no_denoising", epochs = 25, batch_size = 75, colab=0):
#      46     # load partitions
# ---> 47     X_train, X_val, X_test, y_train, y_val, y_test = load_partitions(preprocessing_method, colab)
#      49     datasets = {
#      50         "X_test": X_test,
#      51         "y_test": y_test,
# ...
