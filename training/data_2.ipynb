# %%
import os
import shutil
from pathlib import Path
import pandas as pd
from PIL import Image

# %%
PATH_CSV = "../Datasets/CBIS-DDSM/archive/csv"
PATH_IMAGES = "../Datasets/CBIS-DDSM/archive/jpeg"
CALC_CASE_DESC_TEST_SET_CSV = os.path.join(PATH_CSV, "calc_case_description_test_set.csv")
CALC_CASE_DESC_TRAIN_SET_CSV = os.path.join(PATH_CSV, "calc_case_description_train_set.csv")
DICOM_INFO_CSV = os.path.join(PATH_CSV, "dicom_info.csv")
MASS_CASE_DESC_TEST_SET_CSV = os.path.join(PATH_CSV, "mass_case_description_test_set.csv")
MASS_CASE_DESC_TRAIN_SET_CSV = os.path.join(PATH_CSV, "mass_case_description_train_set.csv")
META_CSV = os.path.join(PATH_CSV, "meta.csv")

# %%
CLASSES = {0 : 'MALIGNANT', 1:  'BENIGN', 2: 'BENIGN_WITHOUT_CALLBACK'}

# %%
df_train = pd.read_csv(CALC_CASE_DESC_TRAIN_SET_CSV)
#display(df_train)

df_test = pd.read_csv(CALC_CASE_DESC_TEST_SET_CSV)
display(df_test)
# Out:
#     patient_id  breast density left or right breast image view  \
# 0      P_00038               2                 LEFT         CC
# 1      P_00038               2                 LEFT        MLO
# 2      P_00038               2                RIGHT         CC
# 3      P_00038               2                RIGHT         CC
# 4      P_00038               2                RIGHT        MLO
# ..         ...             ...                  ...        ...
# 321    P_02464               2                RIGHT        MLO
# 322    P_02498               4                RIGHT         CC
# 323    P_02498               4                RIGHT        MLO
# 324    P_02501               3                RIGHT         CC
# 325    P_02501               3                RIGHT        MLO
#
#      abnormality id abnormality type              calc type calc distribution  \
# 0                 1    calcification   PUNCTATE-PLEOMORPHIC         CLUSTERED
# ...

# %%
df_train.drop('cropped image file path', axis = 1, inplace=True)
df_train.drop('ROI mask file path', axis = 1, inplace=True)

df_test.drop('cropped image file path', axis=1, inplace=True)
df_test.drop('ROI mask file path', axis=1, inplace=True)

def tronca(stringa):
    return stringa.split('/')[-2]

df_train['image file path'] = df_train['image file path'].apply(tronca)
df_test['image file path'] = df_test['image file path'].apply(tronca)

display(df_train)
display(df_test)
# Out:
#      patient_id  breast density left or right breast image view  \
# 0       P_00005               3                RIGHT         CC
# 1       P_00005               3                RIGHT        MLO
# 2       P_00007               4                 LEFT         CC
# 3       P_00007               4                 LEFT        MLO
# 4       P_00008               1                 LEFT         CC
# ...         ...             ...                  ...        ...
# 1541    P_02566               2                RIGHT        MLO
# 1542    P_02572               2                 LEFT         CC
# 1543    P_02572               2                 LEFT        MLO
# 1544    P_02584               1                 LEFT         CC
# 1545    P_02584               1                 LEFT        MLO
#
#       abnormality id abnormality type              calc type  \
# 0                  1    calcification              AMORPHOUS
# 1                  1    calcification              AMORPHOUS
# ...

# %%
# Cerca la prima immagine JPEG nella cartella
for filename in os.listdir(path):
    if filename.lower().endswith(('.jpeg', '.jpg')):
        img_path = os.path.join(path, filename)
        img = Image.open(img_path)
        img.show()
        break

# %%
# create directories
os.makedirs("images", exist_ok=True)
os.makedirs("images/train", exist_ok=True)
os.makedirs("images/test", exist_ok=True)

# %%
folders = []

DEST = "./images"
DEST_TRAIN = os.path.join(DEST, 'train')
DEST_TEST = os.path.join(DEST, 'test')

# %%
for index, row in df_train.iterrows():
    folders.append(os.path.join(PATH_IMAGES, row['image file path']))

display(folders)
print(len(folders))
# Out:
# ['../Datasets/CBIS-DDSM/archive/jpeg\\1.3.6.1.4.1.9590.100.1.2.47414316010368386519740343172775938548',
#  '../Datasets/CBIS-DDSM/archive/jpeg\\1.3.6.1.4.1.9590.100.1.2.250596608311207922527805669693579696727',
#  '../Datasets/CBIS-DDSM/archive/jpeg\\1.3.6.1.4.1.9590.100.1.2.228699627313487111012474405462022068297',
#  '../Datasets/CBIS-DDSM/archive/jpeg\\1.3.6.1.4.1.9590.100.1.2.104743410411133110629448544090466900446',
#  '../Datasets/CBIS-DDSM/archive/jpeg\\1.3.6.1.4.1.9590.100.1.2.406725628213826290127343763811145520834',
#  '../Datasets/CBIS-DDSM/archive/jpeg\\1.3.6.1.4.1.9590.100.1.2.406725628213826290127343763811145520834',
#  '../Datasets/CBIS-DDSM/archive/jpeg\\1.3.6.1.4.1.9590.100.1.2.406725628213826290127343763811145520834',
#  '../Datasets/CBIS-DDSM/archive/jpeg\\1.3.6.1.4.1.9590.100.1.2.14784689311239808604822345534163797907',
#  '../Datasets/CBIS-DDSM/archive/jpeg\\1.3.6.1.4.1.9590.100.1.2.14784689311239808604822345534163797907',
# ...

# %%
for folder in folders:
    print(folder)
    for filename in os.listdir(folder):
        #if filename.startswith('1'):
        file_sorgente = os.path.join(folder, filename)
        if os.path.isfile(file_sorgente):
            shutil.copy2(file_sorgente, DEST_TRAIN)
# Out:
# ../Datasets/CBIS-DDSM/archive/jpeg\1.3.6.1.4.1.9590.100.1.2.47414316010368386519740343172775938548
# ../Datasets/CBIS-DDSM/archive/jpeg\1.3.6.1.4.1.9590.100.1.2.250596608311207922527805669693579696727
# ../Datasets/CBIS-DDSM/archive/jpeg\1.3.6.1.4.1.9590.100.1.2.228699627313487111012474405462022068297
# ../Datasets/CBIS-DDSM/archive/jpeg\1.3.6.1.4.1.9590.100.1.2.104743410411133110629448544090466900446
# ../Datasets/CBIS-DDSM/archive/jpeg\1.3.6.1.4.1.9590.100.1.2.406725628213826290127343763811145520834
# ../Datasets/CBIS-DDSM/archive/jpeg\1.3.6.1.4.1.9590.100.1.2.406725628213826290127343763811145520834
# ../Datasets/CBIS-DDSM/archive/jpeg\1.3.6.1.4.1.9590.100.1.2.406725628213826290127343763811145520834
# ../Datasets/CBIS-DDSM/archive/jpeg\1.3.6.1.4.1.9590.100.1.2.14784689311239808604822345534163797907
# ../Datasets/CBIS-DDSM/archive/jpeg\1.3.6.1.4.1.9590.100.1.2.14784689311239808604822345534163797907
# ...
