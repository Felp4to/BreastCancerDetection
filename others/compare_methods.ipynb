# %%
import sys
import os

# %%
current_folder = os.getcwd()
other_folder = os.path.join(current_folder, '../py')
sys.path.append(os.path.abspath(other_folder))

# %%
import clahe as clahe   
import he as he
import wavelet as wavelet
import fuzzy as fuzzy
import no_denoising as nd
import preprocessing2 as pre
from PIL import Image

# %%
IMG_PATH = '../../images/1-126.jpg'
target_size = (224, 224, 3)
target_size = None

# %%
#clahe.apply_equalization_clahe(IMG_PATH, target_size, 1, 1, 2.0, (15, 15))
clahe_img = clahe.apply_equalization_clahe(IMG_PATH, target_size, 0, 1, 2.0, (8, 8))

# %%
img_fuzzy = fuzzy.FuzzyContrastEnhance(IMG_PATH, target_size, 1)

# %%
img_he = he.apply_histogram_equalization(IMG_PATH, target_size, 0, 1)

# %%
img_wavelet = wavelet.apply_wavelet_denoising(IMG_PATH, target_size, 0, 1)

# %%
no_denoised = nd.no_denoising(IMG_PATH, target_size)

# %%
images = [no_denoised, clahe_img, img_fuzzy, img_he, img_wavelet]
titles = ['original', 'clahe','fuzzy','he','wavelet']

pre.show_comparison(images, titles)
