# %%
import sys
import constants as cs
import tensorflow as tf

# %%
sys.path.append('../explanability/gradCAM.py')
import gradCAM as gradCAM

# %%
model = tf.keras.models.load_model("../models/colab/model.keras")

# %%
gradCAM.compute_gradcam(model, cs.PATH_IMAGES_CANCER, 'fuzzy')
# Out:
# [(<tf.Tensor: shape=(1, 50, 50, 3), dtype=float32, numpy=
#   array([[[[0.93333334, 0.88235295, 0.9137255 ],
#            [0.85882354, 0.7137255 , 0.8039216 ],
#            [0.87058824, 0.6784314 , 0.78431374],
#            ...,
#            [0.28235295, 0.14117648, 0.34901962],
#            [0.5137255 , 0.3254902 , 0.52156866],
#            [0.5686275 , 0.3019608 , 0.48235294]],
#
#           [[0.94509804, 0.9137255 , 0.94509804],
#            [0.8784314 , 0.8       , 0.8352941 ],
#            [0.88235295, 0.7764706 , 0.84705883],
#            ...,
#            [0.30588236, 0.17254902, 0.38039216],
#            [0.44313726, 0.24705882, 0.44313726],
#            [0.6745098 , 0.42352942, 0.6       ]],
#
#           [[0.9490196 , 0.9098039 , 0.9254902 ],
#            [0.92156863, 0.88235295, 0.9019608 ],
#            [0.9098039 , 0.78431374, 0.8509804 ],
#            ...,
#            [0.47843137, 0.33333334, 0.5137255 ],
#            [0.49411765, 0.27058825, 0.49019608],
# ...
